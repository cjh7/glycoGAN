# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install --upgrade scipy
# Out:
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy) (1.23.5)

# %%
import scipy
scipy.__version__
# Out:
# '1.11.4'

# %%
import matplotlib.pyplot as plt
import os
import numpy as np
import pandas as pd
import math
from scipy.stats import ttest_rel
from scipy import stats

# %%
import glob


propose_fscore = []
propose_fscore_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/PROPOSE')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
filelist=sorted(filelist)
a = 0
for file in filelist:
  print(file)
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  propose_fscore_sd.append(result[148:149])


print("propose")
print(a/len(filelist))
propose_fscore.append(a/len(filelist))
print(len(filelist))
print(np.std(propose_fscore_sd))

print(a/len(filelist)-1.96*(np.std(propose_fscore_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(propose_fscore_sd)/math.sqrt(len(filelist))))


bagangp_fscore = []
bagangp_fscore_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/BAGANGP')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
filelist=sorted(filelist)
a = 0
for file in filelist:
  print(file)
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  bagangp_fscore_sd.append(result[148:149])


print("bagangp")
print(a/len(filelist))
bagangp_fscore .append(a/len(filelist))
print(len(filelist))
print(np.std(bagangp_fscore_sd))
print(a/len(filelist)-1.96*(np.std(bagangp_fscore_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(bagangp_fscore_sd)/math.sqrt(len(filelist))))

cdragan_fscore= []
cdragan_fscore_sd= []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/CDRAGAN')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  cdragan_fscore_sd.append(result[148:149])

print("cdragan")
print(a/len(filelist))
cdragan_fscore.append(a/len(filelist))
print(len(filelist))
print(np.std(cdragan_fscore_sd))
print(a/len(filelist)-1.96*(np.std(cdragan_fscore_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(cdragan_fscore_sd)/math.sqrt(len(filelist))))


noaug_fscore = []
noaug_fscore_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/NOAUG')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  noaug_fscore_sd.append(result[148:149])

print("noaug")
print(a/len(filelist))
noaug_fscore.append(a/len(filelist))
print(len(filelist))
print(np.std(noaug_fscore_sd))
print(a/len(filelist)-1.96*(np.std(noaug_fscore_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(noaug_fscore_sd)/math.sqrt(len(filelist))))



smote_fscore = []
smote_fscore_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/SMOTE')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  smote_fscore_sd.append(result[148:149])

print("smote")
print(a/len(filelist))
smote_fscore .append(a/len(filelist))
print(len(filelist))
print(np.std(smote_fscore_sd))
print(a/len(filelist)-1.96*(np.std(smote_fscore_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(smote_fscore_sd)/math.sqrt(len(filelist))))


bsmote_fscore = []
bsmote_fscore_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/BSMOTE')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  bsmote_fscore_sd.append(result[148:149])

print("bsmote")
print(a/len(filelist))
bsmote_fscore .append(a/len(filelist))
print(len(filelist))
print(np.std(bsmote_fscore_sd))
print(a/len(filelist)-1.96*(np.std(bsmote_fscore_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(bsmote_fscore_sd)/math.sqrt(len(filelist))))


adasyn_fscore = []
adasyn_fscore_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/ADASYN')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  adasyn_fscore_sd.append(result[148:149])

print("adasyn")
print(a/len(filelist))
adasyn_fscore .append(a/len(filelist))
print(len(filelist))
print(np.std(adasyn_fscore_sd))
print(a/len(filelist)-1.96*(np.std(adasyn_fscore_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(adasyn_fscore_sd)/math.sqrt(len(filelist))))


cooperative_fscore =[]
cooperative_fscore_sd =[]

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/COOPERATIVE')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  print(file)
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  cooperative_fscore_sd.append(result[148:149])

print("cooperative")
print(a/len(filelist))
cooperative_fscore.append(a/len(filelist))
print(len(filelist))
print(np.std(cooperative_fscore_sd))
print(a/len(filelist)-1.96*(np.std(cooperative_fscore_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(cooperative_fscore_sd)/math.sqrt(len(filelist))))



cooperative_fscore =[]
cooperative_fscore_sd =[]

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/COOPERATIVE/9')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  print(file)
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  cooperative_fscore_sd.append(result[148:149])

print("cooperative")
print(a/len(filelist))
cooperative_fscore.append(a/len(filelist))
print(len(filelist))
print(np.std(cooperative_fscore_sd))
print(a/len(filelist)-1.96*(np.std(cooperative_fscore_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(cooperative_fscore_sd)/math.sqrt(len(filelist))))
# Out:
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/PROPOSE/test_0_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/PROPOSE/test_1_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/PROPOSE/test_2_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/PROPOSE/test_3_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/PROPOSE/test_4_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/PROPOSE/test_5_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/PROPOSE/test_6_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/PROPOSE/test_7_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/PROPOSE/test_8_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/PROPOSE/test_9_EBM.CSV
# propose
# 0.8921330330139139
# 10
# 0.021841788429344314
# 0.8785953522906988
# 0.9056707137371289
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/BAGANGP/test_0_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/BAGANGP/test_1_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/BAGANGP/test_2_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/BAGANGP/test_3_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/BAGANGP/test_4_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/BAGANGP/test_5_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/BAGANGP/test_6_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/BAGANGP/test_7_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/BAGANGP/test_8_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/BAGANGP/test_9_EBM.CSV
# bagangp
# 0.8600767462026875
# 10
# 0.0321736717199512
# 0.8401352978708713
# 0.8800181945345037
# cdragan
# 0.8141936567338769
# 10
# 0.04548084627478288
# 0.7860043361623784
# 0.8423829773053754
# noaug
# 0.8798300803040148
# 10
# 0.024481380071993946
# 0.8646563637308302
# 0.8950037968771993
# smote
# 0.7924075289348642
# 10
# 0.05695132432779489
# 0.7571087324096615
# 0.827706325460067
# bsmote
# 0.8011423264550805
# 10
# 0.05980926908842929
# 0.76407215741525
# 0.8382124954949111
# adasyn
# 0.7861907041572226
# 10
# 0.05480810394718859
# 0.75222028938638
# 0.8201611189280652
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/COOPERATIVE/test_0_EBM_1.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/COOPERATIVE/test_1_EBM_1.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/COOPERATIVE/test_2_EBM_1.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/COOPERATIVE/test_3_EBM_1.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/COOPERATIVE/test_4_EBM_1.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/COOPERATIVE/test_5_EBM_1.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/COOPERATIVE/test_6_EBM_1.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/COOPERATIVE/test_7_EBM_1.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/COOPERATIVE/test_8_EBM_1.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/COOPERATIVE/test_9_EBM_1.CSV
# cooperative
# 0.8189084835342342
# 10
# 0.03347938501226322
# 0.7981577457193448
# 0.8396592213491235
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/COOPERATIVE/9/test_0_EBM_9.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/COOPERATIVE/9/test_1_EBM_9.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/COOPERATIVE/9/test_2_EBM_9.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/COOPERATIVE/9/test_3_EBM_9.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/COOPERATIVE/9/test_4_EBM_9.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/COOPERATIVE/9/test_5_EBM_9.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/COOPERATIVE/9/test_6_EBM_9.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/COOPERATIVE/9/test_7_EBM_9.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/COOPERATIVE/9/test_8_EBM_9.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/FSCORE/COOPERATIVE/9/test_9_EBM_9.CSV
# cooperative
# 0.834924941003797
# 10
# 0.030694580108309628
# 0.8159002431507048
# 0.8539496388568892

# %%
r=[]
for i in range(10):
  r.append(propose_fscore_sd[i]-noaug_fscore_sd[i])
print(stats.shapiro(r))
# Out:
# ShapiroResult(statistic=0.9334641695022583, pvalue=0.48281723260879517)

# %%
stat, p = ttest_rel(propose_fscore_sd , noaug_fscore_sd, axis=0, alternative='greater')
# stats.ttest_rel(P1, P2, axis=0, alternative='less')
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('Probably the same distribution')
else:
	print('Probably different distributions')
# Out:
# stat=1.399, p=0.098
# Probably the same distribution

# %%
r=[]
for i in range(10):
  r.append(propose_fscore_sd[i]-noaug_fscore_sd[i])
print(stats.shapiro(r))

stat, p = ttest_rel(propose_fscore_sd , noaug_fscore_sd, axis=0, alternative='greater')
# stats.ttest_rel(P1, P2, axis=0, alternative='less')
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('Probably the same distribution')
else:
	print('Probably different distributions')
# Out:
# ShapiroResult(statistic=0.9334641695022583, pvalue=0.48281723260879517)
# stat=1.399, p=0.098
# Probably the same distribution

# %%
print(  (np.mean(propose_fscore_sd)-np.mean(bagangp_fscore_sd))  / np.mean(bagangp_fscore_sd) *100 )
print(  (np.mean(propose_fscore_sd)-np.mean(cdragan_fscore_sd))  / np.mean(cdragan_fscore_sd) *100 )
print(  (np.mean(propose_fscore_sd)-np.mean(noaug_fscore_sd))  / np.mean(noaug_fscore_sd) *100 )
print(  (np.mean(propose_fscore_sd)-np.mean(smote_fscore_sd))  / np.mean(smote_fscore_sd) *100 )
print(  (np.mean(propose_fscore_sd)-np.mean(bsmote_fscore_sd))  / np.mean(bsmote_fscore_sd) *100 )
print(  (np.mean(propose_fscore_sd)-np.mean(adasyn_fscore_sd))  / np.mean(adasyn_fscore_sd) *100 )
print(  (np.mean(propose_fscore_sd)-np.mean(cooperative_fscore_sd))  / np.mean(cooperative_fscore_sd) *100 )
# Out:
# 3.7271426012571154
# 9.572584560863492
# 1.3983328128140355
# 12.585128287851866
# 11.357620681639894
# 13.475398309403685
# 6.851884427040591

# %%
import glob



propose_recall = []
propose_recall_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/PROPOSE')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
filelist=sorted(filelist)
a = 0
for file in filelist:
  print(file)
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  propose_recall_sd.append(result[148:149])

print("propose")
print(a/len(filelist))
propose_recall.append(a/len(filelist))
print(len(filelist))
print(np.std(propose_recall_sd))
print(a/len(filelist)-1.96*(np.std(propose_recall_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(propose_recall_sd)/math.sqrt(len(filelist))))



bagangp_recall = []
bagangp_recall_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/BAGANGP')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  print(file)
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  bagangp_recall_sd.append(result[148:149])

print("bagangp")
print(a/len(filelist))
bagangp_recall.append(a/len(filelist))
print(len(filelist))
print(np.std(bagangp_recall_sd))

print(a/len(filelist)-1.96*(np.std(bagangp_recall_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(bagangp_recall_sd)/math.sqrt(len(filelist))))

cdragan_recall = []
cdragan_recall_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/CDRAGAN')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  print(file)
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  cdragan_recall_sd.append(result[148:149])

print("cdragan")
print(a/len(filelist))
cdragan_recall .append(a/len(filelist))
print(len(filelist))
print(np.std(cdragan_recall_sd))
print(a/len(filelist)-1.96*(np.std(cdragan_recall_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(cdragan_recall_sd)/math.sqrt(len(filelist))))


noaug_recall  = []
noaug_recall_sd  = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/NOAUG')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  noaug_recall_sd.append(result[148:149])

print("noaug")
print(a/len(filelist))
noaug_recall.append(a/len(filelist))
print(len(filelist))
print(np.std(noaug_recall_sd))
print(a/len(filelist)-1.96*(np.std(noaug_recall_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(noaug_recall_sd)/math.sqrt(len(filelist))))

smote_recall = []
smote_recall_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/SMOTE')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  smote_recall_sd.append(result[148:149])

print("smote")
print(a/len(filelist))
smote_recall.append(a/len(filelist))
print(len(filelist))
print(np.std(smote_recall_sd))
print(a/len(filelist)-1.96*(np.std(smote_recall_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(smote_recall_sd)/math.sqrt(len(filelist))))


bsmote_recall= []
bsmote_recall_sd= []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/BSMOTE')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  bsmote_recall_sd.append(result[148:149])

print("bsmote")
print(a/len(filelist))
bsmote_recall.append(a/len(filelist))
print(len(filelist))
print(np.std(bsmote_recall_sd))
print(a/len(filelist)-1.96*(np.std(bsmote_recall_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(bsmote_recall_sd)/math.sqrt(len(filelist))))


adasyn_recall = []
adasyn_recall_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/ADASYN')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  adasyn_recall_sd.append(result[148:149])

print("adasyn")
print(a/len(filelist))
adasyn_recall.append(a/len(filelist))
print(len(filelist))
print(np.std(adasyn_recall_sd))

print(a/len(filelist)-1.96*(np.std(adasyn_recall_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(adasyn_recall_sd)/math.sqrt(len(filelist))))

cooperative_recall = []
cooperative_recall_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/COOPERATIVE')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  print(file)
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  cooperative_recall_sd.append(result[148:149])

print("cooperative")
print(a/len(filelist))
cooperative_recall.append(a/len(filelist))
print(len(filelist))
print(np.std(cooperative_recall_sd))
print(a/len(filelist)-1.96*(np.std(cooperative_recall_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(cooperative_recall_sd)/math.sqrt(len(filelist))))



cooperative_recall = []
cooperative_recall_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/COOPERATIVE/9')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  print(file)
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  cooperative_recall_sd.append(result[148:149])

print("cooperative")
print(a/len(filelist))
cooperative_recall.append(a/len(filelist))
print(len(filelist))
print(np.std(cooperative_recall_sd))
print(a/len(filelist)-1.96*(np.std(cooperative_recall_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(cooperative_recall_sd)/math.sqrt(len(filelist))))
# Out:
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/PROPOSE/recall_0_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/PROPOSE/recall_1_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/PROPOSE/recall_2_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/PROPOSE/recall_3_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/PROPOSE/recall_4_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/PROPOSE/recall_5_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/PROPOSE/recall_6_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/PROPOSE/recall_7_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/PROPOSE/recall_8_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/PROPOSE/recall_9_EBM.CSV
# propose
# 0.897557352698465
# 10
# 0.020666817291113443
# 0.884747926631677
# 0.9103667787652531
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/BAGANGP/recall_0_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/BAGANGP/recall_1_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/BAGANGP/recall_2_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/BAGANGP/recall_3_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/BAGANGP/recall_4_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/BAGANGP/recall_5_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/BAGANGP/recall_6_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/BAGANGP/recall_7_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/BAGANGP/recall_8_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/BAGANGP/recall_9_EBM.CSV
# bagangp
# 0.8683693678824888
# 10
# 0.02937410964655726
# 0.8501631061008504
# 0.8865756296641271
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/CDRAGAN/recall_0_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/CDRAGAN/recall_1_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/CDRAGAN/recall_2_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/CDRAGAN/recall_3_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/CDRAGAN/recall_4_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/CDRAGAN/recall_5_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/CDRAGAN/recall_6_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/CDRAGAN/recall_7_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/CDRAGAN/recall_8_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/CDRAGAN/recall_9_EBM.CSV
# cdragan
# 0.8257303185344116
# 10
# 0.04000273079633909
# 0.800936369113585
# 0.8505242679552382
# noaug
# 0.88619409143423
# 10
# 0.02288405804259125
# 0.8720104053119018
# 0.9003777775565582
# smote
# 0.8079633602904769
# 10
# 0.050310212813571425
# 0.7767807673269768
# 0.839145953253977
# bsmote
# 0.8157946855916818
# 10
# 0.052291429848533307
# 0.7833841215877391
# 0.8482052495956245
# adasyn
# 0.8026241954117841
# 10
# 0.04724743861657349
# 0.7733399295628601
# 0.831908461260708
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/COOPERATIVE/recall_0_EBM_1.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/COOPERATIVE/recall_1_EBM_1.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/COOPERATIVE/recall_2_EBM_1.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/COOPERATIVE/recall_3_EBM_1.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/COOPERATIVE/recall_4_EBM_1.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/COOPERATIVE/recall_5_EBM_1.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/COOPERATIVE/recall_6_EBM_1.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/COOPERATIVE/recall_7_EBM_1.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/COOPERATIVE/recall_8_EBM_1.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/COOPERATIVE/recall_9_EBM_1.CSV
# cooperative
# 0.8290146888925566
# 10
# 0.030400388750415296
# 0.8101723327322056
# 0.8478570450529076
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/COOPERATIVE/9/recall_0_EBM_9.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/COOPERATIVE/9/recall_1_EBM_9.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/COOPERATIVE/9/recall_2_EBM_9.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/COOPERATIVE/9/recall_3_EBM_9.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/COOPERATIVE/9/recall_4_EBM_9.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/COOPERATIVE/9/recall_5_EBM_9.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/COOPERATIVE/9/recall_6_EBM_9.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/COOPERATIVE/9/recall_7_EBM_9.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/COOPERATIVE/9/recall_8_EBM_9.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/RECALL/COOPERATIVE/9/recall_9_EBM_9.CSV
# cooperative
# 0.8424575012378279
# 10
# 0.027723527163511036
# 0.8252742810782204
# 0.8596407213974354

# %%
r=[]
for i in range(10):
  r.append(propose_recall_sd[i]-noaug_recall_sd[i])
print(stats.shapiro(r))
# Out:
# ShapiroResult(statistic=0.9379746913909912, pvalue=0.5307060480117798)

# %%
stat, p = ttest_rel(propose_recall_sd, noaug_recall_sd, axis=0, alternative='greater')
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('Probably the same distribution')
else:
	print('Probably different distributions')
# Out:
# stat=1.397, p=0.098
# Probably the same distribution

# %%
r=[]
for i in range(10):
  r.append(propose_recall_sd[i]-noaug_recall_sd[i])
print(stats.shapiro(r))

stat, p = ttest_rel(propose_recall_sd , noaug_recall_sd, axis=0, alternative='greater')
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('Probably the same distribution')
else:
	print('Probably different distributions')
# Out:
# ShapiroResult(statistic=0.9379746913909912, pvalue=0.5307060480117798)
# stat=1.397, p=0.098
# Probably the same distribution

# %%
print(  (np.mean(propose_recall_sd)-np.mean(bagangp_recall_sd))  / np.mean(bagangp_recall_sd) *100 )
print(  (np.mean(propose_recall_sd)-np.mean(cdragan_recall_sd))  / np.mean(cdragan_recall_sd) *100 )
print(  (np.mean(propose_recall_sd)-np.mean(noaug_recall_sd))  / np.mean(noaug_recall_sd) *100 )
print(  (np.mean(propose_recall_sd)-np.mean(smote_recall_sd))  / np.mean(smote_recall_sd) *100 )
print(  (np.mean(propose_recall_sd)-np.mean(bsmote_recall_sd))  / np.mean(bsmote_recall_sd) *100 )
print(  (np.mean(propose_recall_sd)-np.mean(adasyn_recall_sd))  / np.mean(adasyn_recall_sd) *100 )
print(  (np.mean(propose_recall_sd)-np.mean(cooperative_recall_sd))  / np.mean(cooperative_recall_sd) *100 )
# Out:
# 3.361240722614495
# 8.69860686374446
# 1.2822542346050358
# 11.088868234789453
# 10.022456452689713
# 11.827846435401284
# 6.540371636513232

# %%
import glob

propose_precision = []
propose_precision_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/PROPOSE')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
filelist=sorted(filelist)
a = 0
for file in filelist:
  print(file)
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  propose_precision_sd.append(result[148:149])

print("propose")
print(a/len(filelist))
propose_precision.append(a/len(filelist))
print(len(filelist))
print(np.std(propose_precision_sd))
print(a/len(filelist)-1.96*(np.std(propose_precision_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(propose_precision_sd)/math.sqrt(len(filelist))))

bagangp_precision  = []
bagangp_precision_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/BAGANGP')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  print(file)
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  bagangp_precision_sd.append(result[148:149])

print("bagangp")
print(a/len(filelist))
bagangp_precision .append(a/len(filelist))
print(len(filelist))
print(np.std(bagangp_precision_sd))
print(a/len(filelist)-1.96*(np.std(bagangp_precision_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(bagangp_precision_sd)/math.sqrt(len(filelist))))


cdragan_precision  = []
cdragan_precision_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/CDRAGAN')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  cdragan_precision_sd.append(result[148:149])

print("cdragan")
print(a/len(filelist))
cdragan_precision .append(a/len(filelist))
print(len(filelist))
print(np.std(cdragan_precision_sd))
print(a/len(filelist)-1.96*(np.std(cdragan_precision_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(cdragan_precision_sd)/math.sqrt(len(filelist))))



noaug_precision = []
noaug_precision_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/NOAUG')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  print(file)
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  noaug_precision_sd.append(result[148:149])

print("noaug")
print(a/len(filelist))
noaug_precision.append(a/len(filelist))
print(len(filelist))
print(np.std(noaug_precision_sd))
print(a/len(filelist)-1.96*(np.std(noaug_precision_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(noaug_precision_sd)/math.sqrt(len(filelist))))


smote_precision = []
smote_precision_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/SMOTE')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  smote_precision_sd.append(result[148:149])

print("smote")
print(a/len(filelist))
smote_precision .append(a/len(filelist))
print(len(filelist))
print(np.std(smote_precision_sd))
print(a/len(filelist)-1.96*(np.std(smote_precision_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(smote_precision_sd)/math.sqrt(len(filelist))))



bsmote_precision  = []
bsmote_precision_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/BSMOTE')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  bsmote_precision_sd.append(result[148:149])

print("bsmote")
print(a/len(filelist))
bsmote_precision .append(a/len(filelist))
print(len(filelist))
print(np.std(bsmote_precision_sd))
print(a/len(filelist)-1.96*(np.std(bsmote_precision_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(bsmote_precision_sd)/math.sqrt(len(filelist))))




adasyn_precision = []
adasyn_precision_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/ADASYN')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  adasyn_precision_sd.append(result[148:149])

print("adasyn")
print(a/len(filelist))
adasyn_precision .append(a/len(filelist))
print(len(filelist))
print(np.std(adasyn_precision_sd))
print(a/len(filelist)-1.96*(np.std(adasyn_precision_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(adasyn_precision_sd)/math.sqrt(len(filelist))))




cooperative_precision = []
cooperative_precision_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/COOPERATIVE')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  cooperative_precision_sd.append(result[148:149])

print("cooperative")
print(a/len(filelist))
cooperative_precision .append(a/len(filelist))
print(len(filelist))
print(np.std(cooperative_precision_sd))
print(a/len(filelist)-1.96*(np.std(cooperative_precision_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(cooperative_precision_sd)/math.sqrt(len(filelist))))




cooperative_precision = []
cooperative_precision_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/COOPERATIVE/9')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  cooperative_precision_sd.append(result[148:149])

print("cooperative")
print(a/len(filelist))
cooperative_precision .append(a/len(filelist))
print(len(filelist))
print(np.std(cooperative_precision_sd))
print(a/len(filelist)-1.96*(np.std(cooperative_precision_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(cooperative_precision_sd)/math.sqrt(len(filelist))))
# Out:
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/PROPOSE/precision_0_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/PROPOSE/precision_1_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/PROPOSE/precision_2_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/PROPOSE/precision_3_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/PROPOSE/precision_4_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/PROPOSE/precision_5_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/PROPOSE/precision_6_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/PROPOSE/precision_7_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/PROPOSE/precision_8_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/PROPOSE/precision_9_EBM.CSV
# propose
# 0.9020641855001671
# 10
# 0.017496309115520133
# 0.8912198607596908
# 0.9129085102406433
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/BAGANGP/precision_0_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/BAGANGP/precision_1_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/BAGANGP/precision_2_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/BAGANGP/precision_3_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/BAGANGP/precision_4_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/BAGANGP/precision_5_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/BAGANGP/precision_6_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/BAGANGP/precision_7_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/BAGANGP/precision_8_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/BAGANGP/precision_9_EBM.CSV
# bagangp
# 0.8812207384107312
# 10
# 0.020684575260140694
# 0.8684003058407092
# 0.8940411709807533
# cdragan
# 0.8480362872550756
# 10
# 0.02597997146113517
# 0.8319337341158571
# 0.8641388403942941
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/NOAUG/precision_0_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/NOAUG/precision_1_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/NOAUG/precision_2_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/NOAUG/precision_3_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/NOAUG/precision_4_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/NOAUG/precision_5_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/NOAUG/precision_6_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/NOAUG/precision_7_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/NOAUG/precision_8_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/glyco_scale/glyco/imbalanceGAN/RESULT/PRECISION/NOAUG/precision_9_EBM.CSV
# noaug
# 0.8931225064185636
# 10
# 0.01863656246295522
# 0.8815714453313321
# 0.9046735675057951
# smote
# 0.8411116693705084
# 10
# 0.03240725986190973
# 0.821025441608345
# 0.8611978971326718
# bsmote
# 0.8458926578616754
# 10
# 0.034777199082123005
# 0.8243375265525128
# 0.8674477891708381
# adasyn
# 0.8378587247339331
# 10
# 0.030450556743797565
# 0.8189852741291354
# 0.8567321753387308
# cooperative
# 0.8467538490656263
# 10
# 0.023903360948764617
# 0.8319383924567073
# 0.8615693056745454
# cooperative
# 0.8558471600403588
# 10
# 0.025139399742380837
# 0.8402655986500656
# 0.871428721430652

# %%
r=[]
for i in range(10):
  r.append(propose_precision_sd[i]-noaug_precision_sd[i])
print(stats.shapiro(r))
# Out:
# ShapiroResult(statistic=0.9453544020652771, pvalue=0.6139727234840393)

# %%
stat, p = ttest_rel(propose_precision_sd , noaug_precision_sd, axis=0, alternative='greater')
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('Probably the same distribution')
else:
	print('Probably different distributions')
# Out:
# stat=1.438, p=0.092
# Probably the same distribution

# %%
r=[]
for i in range(10):
  r.append(propose_precision_sd[i]-noaug_precision_sd[i])
print(stats.shapiro(r))

stat, p = ttest_rel(propose_precision_sd , noaug_precision_sd, axis=0, alternative='greater')
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('Probably the same distribution')
else:
	print('Probably different distributions')
# Out:
# ShapiroResult(statistic=0.9453544020652771, pvalue=0.6139727234840393)
# stat=1.438, p=0.092
# Probably the same distribution

# %%
print(  (np.mean(propose_precision_sd)-np.mean(bagangp_precision_sd))  / np.mean(bagangp_precision_sd) *100 )
print(  (np.mean(propose_precision_sd)-np.mean(cdragan_precision_sd))  / np.mean(cdragan_precision_sd) *100 )
print(  (np.mean(propose_precision_sd)-np.mean(noaug_precision_sd))  / np.mean(noaug_precision_sd) *100 )
print(  (np.mean(propose_precision_sd)-np.mean(smote_precision_sd))  / np.mean(smote_precision_sd) *100 )
print(  (np.mean(propose_precision_sd)-np.mean(bsmote_precision_sd))  / np.mean(bsmote_precision_sd) *100 )
print(  (np.mean(propose_precision_sd)-np.mean(adasyn_precision_sd))  / np.mean(adasyn_precision_sd) *100 )
print(  (np.mean(propose_precision_sd)-np.mean(cooperative_precision_sd))  / np.mean(cooperative_precision_sd) *100 )
# Out:
# 2.3652923928035268
# 6.370941793065102
# 1.0011705020691568
# 7.246661572924771
# 6.640503037405171
# 7.663041378082276
# 5.400149421262176
