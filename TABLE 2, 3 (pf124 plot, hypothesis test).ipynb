# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install --upgrade scipy

# %%
import scipy
scipy.__version__
# Out:
# '1.11.4'

# %%
import matplotlib.pyplot as plt
import os
import numpy as np
import pandas as pd
import math
from scipy.stats import ttest_rel
from scipy import stats
from scipy.stats import pearsonr

# %%
import glob


propose_fscore = []
propose_fscore_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/FSCORE/PROPOSE')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
filelist=sorted(filelist)
a = 0
for file in filelist:
  print(file)
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  propose_fscore_sd.append(result[148:149])


print("propose")
print(a/len(filelist))
propose_fscore.append(a/len(filelist))
print(len(filelist))
print(np.std(propose_fscore_sd))

print(a/len(filelist)-1.96*(np.std(propose_fscore_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(propose_fscore_sd)/math.sqrt(len(filelist))))


bagangp_fscore = []
bagangp_fscore_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/FSCORE/BAGANGP')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
filelist=sorted(filelist)
a = 0
for file in filelist:
  print(file)
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  bagangp_fscore_sd.append(result[148:149])


print("bagangp")
print(a/len(filelist))
bagangp_fscore .append(a/len(filelist))
print(len(filelist))
print(np.std(bagangp_fscore_sd))
print(a/len(filelist)-1.96*(np.std(bagangp_fscore_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(bagangp_fscore_sd)/math.sqrt(len(filelist))))

cdragan_fscore= []
cdragan_fscore_sd= []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/FSCORE/CDRAGAN')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  print(file)
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  cdragan_fscore_sd.append(result[148:149])

print("cdragan")
print(a/len(filelist))
cdragan_fscore.append(a/len(filelist))
print(len(filelist))
print(np.std(cdragan_fscore_sd))
print(a/len(filelist)-1.96*(np.std(cdragan_fscore_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(cdragan_fscore_sd)/math.sqrt(len(filelist))))


noaug_fscore = []
noaug_fscore_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/FSCORE/NOAUG')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  print(file)
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  noaug_fscore_sd.append(result[148:149])

print("noaug")
print(a/len(filelist))
noaug_fscore.append(a/len(filelist))
print(len(filelist))
print(np.std(noaug_fscore_sd))
print(a/len(filelist)-1.96*(np.std(noaug_fscore_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(noaug_fscore_sd)/math.sqrt(len(filelist))))



smote_fscore = []
smote_fscore_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/FSCORE/SMOTE')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  smote_fscore_sd.append(result[148:149])

print("smote")
print(a/len(filelist))
smote_fscore .append(a/len(filelist))
print(len(filelist))
print(np.std(smote_fscore_sd))
print(a/len(filelist)-1.96*(np.std(smote_fscore_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(smote_fscore_sd)/math.sqrt(len(filelist))))


bsmote_fscore = []
bsmote_fscore_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/FSCORE/BSMOTE')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  bsmote_fscore_sd.append(result[148:149])

print("bsmote")
print(a/len(filelist))
bsmote_fscore .append(a/len(filelist))
print(len(filelist))
print(np.std(bsmote_fscore_sd))
print(a/len(filelist)-1.96*(np.std(bsmote_fscore_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(bsmote_fscore_sd)/math.sqrt(len(filelist))))


# adasyn_fscore = []
# adasyn_fscore_sd = []

# os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/FSCORE/ADASYN')
# path = os.getcwd()
# filelist = glob.glob(os.path.join(path, "*.CSV"))
# a = 0
# for file in filelist:
#   result = pd.read_csv(file)
#   result = result.values
#   a = a +np.mean(result[148:149])
#   adasyn_fscore_sd.append(result[148:149])

# print("adasyn")
# print(a/len(filelist))
# adasyn_fscore .append(a/len(filelist))
# print(len(filelist))
# print(np.std(adasyn_fscore_sd))
# print(a/len(filelist)-1.96*(np.std(adasyn_fscore_sd)/math.sqrt(len(filelist))))
# print(a/len(filelist)+1.96*(np.std(adasyn_fscore_sd)/math.sqrt(len(filelist))))


cooperative_fscore =[]
cooperative_fscore_sd =[]

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/FSCORE/COOPERATIVE')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  print(file)
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  cooperative_fscore_sd.append(result[148:149])

print("cooperative")
print(a/len(filelist))
cooperative_fscore.append(a/len(filelist))
print(len(filelist))
print(np.std(cooperative_fscore_sd))
print(a/len(filelist)-1.96*(np.std(cooperative_fscore_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(cooperative_fscore_sd)/math.sqrt(len(filelist))))

cooperative_fscore =[]
cooperative_fscore_sd =[]

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/FSCORE/COOPERATIVE/9')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  print(file)
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  cooperative_fscore_sd.append(result[148:149])

print("cooperative")
print(a/len(filelist))
cooperative_fscore.append(a/len(filelist))
print(len(filelist))
print(np.std(cooperative_fscore_sd))
print(a/len(filelist)-1.96*(np.std(cooperative_fscore_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(cooperative_fscore_sd)/math.sqrt(len(filelist))))
# Out:
# /content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/FSCORE/PROPOSE/test_0_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/FSCORE/PROPOSE/test_1_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/FSCORE/PROPOSE/test_2_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/FSCORE/PROPOSE/test_3_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/FSCORE/PROPOSE/test_4_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/FSCORE/PROPOSE/test_5_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/FSCORE/PROPOSE/test_6_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/FSCORE/PROPOSE/test_7_EBM.CSV
# ...

# %%
r=[]
for i in range(10):
  r.append(propose_fscore_sd[i]-cdragan_fscore_sd[i])
print(stats.shapiro(r))
# Out:
# ShapiroResult(statistic=0.9255443215370178, pvalue=0.405521959066391)

# %%
stat, p = ttest_rel(propose_fscore_sd , cdragan_fscore_sd, axis=0, alternative='greater')
# stats.ttest_rel(P1, P2, axis=0, alternative='less')
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('Probably the same distribution')
else:
	print('Probably different distributions')
# Out:
# stat=0.946, p=0.184
# Probably the same distribution

# %%
r=[]
for i in range(10):
  r.append(propose_fscore_sd[i]-noaug_fscore_sd[i])
print(stats.shapiro(r))

stat, p = ttest_rel(propose_fscore_sd , noaug_fscore_sd, axis=0, alternative='greater')
# stats.ttest_rel(P1, P2, axis=0, alternative='less')
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('Probably the same distribution')
else:
	print('Probably different distributions')
# Out:
# ShapiroResult(statistic=0.9580274820327759, pvalue=0.7631679773330688)
# stat=3.680, p=0.003
# Probably different distributions

# %%
print(stats.pearsonr(np.reshape(np.array(propose_fscore_sd),(10,)),np.reshape(np.array(noaug_fscore_sd ),(10,))))
# Out:
# PearsonRResult(statistic=0.515610618309361, pvalue=0.12715510608450645)

# %%
np.reshape(np.array(propose_fscore_sd),(10,))
# Out:
# array([0.93939394, 0.91330366, 0.89586172, 0.79304939, 0.83622829,
#        0.83858696, 0.84978663, 0.83905903, 0.85442514, 0.94999621])

# %%
np.reshape(np.array(noaug_fscore_sd ),(10,))
# Out:
# array([0.86249045, 0.83858696, 0.81548293, 0.77117175, 0.8685633 ,
#        0.77840909, 0.85218365, 0.68729879, 0.76398467, 0.84645912])

# %%
print(  (np.mean(propose_fscore_sd)-np.mean(bagangp_fscore_sd))  / np.mean(bagangp_fscore_sd) *100 )
print(  (np.mean(propose_fscore_sd)-np.mean(cdragan_fscore_sd))  / np.mean(cdragan_fscore_sd) *100 )
print(  (np.mean(propose_fscore_sd)-np.mean(noaug_fscore_sd))  / np.mean(noaug_fscore_sd) *100 )
print(  (np.mean(propose_fscore_sd)-np.mean(smote_fscore_sd))  / np.mean(smote_fscore_sd) *100 )
print(  (np.mean(propose_fscore_sd)-np.mean(bsmote_fscore_sd))  / np.mean(bsmote_fscore_sd) *100 )
# print(  (np.mean(propose_fscore_sd)-np.mean(adasyn_fscore_sd))  / np.mean(adasyn_fscore_sd) *100 )
print(  (np.mean(propose_fscore_sd)-np.mean(cooperative_fscore_sd))  / np.mean(cooperative_fscore_sd) *100 )
# Out:
# 3.7444749411595044
# 2.1809208890764946
# 7.731463253196874
# 9.356454656962242
# 9.178952825331175
# 6.157903967258382

# %%
import glob



propose_recall = []
propose_recall_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/RECALL/PROPOSE')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
filelist=sorted(filelist)
a = 0
for file in filelist:
  print(file)
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  propose_recall_sd.append(result[148:149])

print("propose")
print(a/len(filelist))
propose_recall.append(a/len(filelist))
print(len(filelist))
print(np.std(propose_recall_sd))
print(a/len(filelist)-1.96*(np.std(propose_recall_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(propose_recall_sd)/math.sqrt(len(filelist))))



bagangp_recall = []
bagangp_recall_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/RECALL/BAGANGP')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  print(file)
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  bagangp_recall_sd.append(result[148:149])

print("bagangp")
print(a/len(filelist))
bagangp_recall.append(a/len(filelist))
print(len(filelist))
print(np.std(bagangp_recall_sd))

print(a/len(filelist)-1.96*(np.std(bagangp_recall_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(bagangp_recall_sd)/math.sqrt(len(filelist))))

cdragan_recall = []
cdragan_recall_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/RECALL/CDRAGAN')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  print(file)
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  cdragan_recall_sd.append(result[148:149])

print("cdragan")
print(a/len(filelist))
cdragan_recall .append(a/len(filelist))
print(len(filelist))
print(np.std(cdragan_recall_sd))
print(a/len(filelist)-1.96*(np.std(cdragan_recall_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(cdragan_recall_sd)/math.sqrt(len(filelist))))


noaug_recall  = []
noaug_recall_sd  = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/RECALL/NOAUG')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  noaug_recall_sd.append(result[148:149])

print("noaug")
print(a/len(filelist))
noaug_recall.append(a/len(filelist))
print(len(filelist))
print(np.std(noaug_recall_sd))
print(a/len(filelist)-1.96*(np.std(noaug_recall_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(noaug_recall_sd)/math.sqrt(len(filelist))))

smote_recall = []
smote_recall_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/RECALL/SMOTE')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  smote_recall_sd.append(result[148:149])

print("smote")
print(a/len(filelist))
smote_recall.append(a/len(filelist))
print(len(filelist))
print(np.std(smote_recall_sd))
print(a/len(filelist)-1.96*(np.std(smote_recall_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(smote_recall_sd)/math.sqrt(len(filelist))))


bsmote_recall= []
bsmote_recall_sd= []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/RECALL/BSMOTE')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  bsmote_recall_sd.append(result[148:149])

print("bsmote")
print(a/len(filelist))
bsmote_recall.append(a/len(filelist))
print(len(filelist))
print(np.std(bsmote_recall_sd))
print(a/len(filelist)-1.96*(np.std(bsmote_recall_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(bsmote_recall_sd)/math.sqrt(len(filelist))))


# adasyn_recall = []
# adasyn_recall_sd = []

# os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/RECALL/ADASYN')
# path = os.getcwd()
# filelist = glob.glob(os.path.join(path, "*.CSV"))
# a = 0
# for file in filelist:
#   result = pd.read_csv(file)
#   result = result.values
#   a = a +np.mean(result[148:149])
#   adasyn_recall_sd.append(result[148:149])

# print("adasyn")
# print(a/len(filelist))
# adasyn_recall.append(a/len(filelist))
# print(len(filelist))
# print(np.std(adasyn_recall_sd))

# print(a/len(filelist)-1.96*(np.std(adasyn_recall_sd)/math.sqrt(len(filelist))))
# print(a/len(filelist)+1.96*(np.std(adasyn_recall_sd)/math.sqrt(len(filelist))))

cooperative_recall = []
cooperative_recall_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/RECALL/COOPERATIVE')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  print(file)
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  cooperative_recall_sd.append(result[148:149])

print("cooperative")
print(a/len(filelist))
cooperative_recall.append(a/len(filelist))
print(len(filelist))
print(np.std(cooperative_recall_sd))
print(a/len(filelist)-1.96*(np.std(cooperative_recall_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(cooperative_recall_sd)/math.sqrt(len(filelist))))

cooperative_recall = []
cooperative_recall_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/RECALL/COOPERATIVE/9')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  print(file)
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  cooperative_recall_sd.append(result[148:149])

print("cooperative")
print(a/len(filelist))
cooperative_recall.append(a/len(filelist))
print(len(filelist))
print(np.std(cooperative_recall_sd))
print(a/len(filelist)-1.96*(np.std(cooperative_recall_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(cooperative_recall_sd)/math.sqrt(len(filelist))))
# Out:
# /content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/RECALL/PROPOSE/recall_0_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/RECALL/PROPOSE/recall_1_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/RECALL/PROPOSE/recall_2_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/RECALL/PROPOSE/recall_3_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/RECALL/PROPOSE/recall_4_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/RECALL/PROPOSE/recall_5_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/RECALL/PROPOSE/recall_6_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/RECALL/PROPOSE/recall_7_EBM.CSV
# ...

# %%
r=[]
for i in range(10):
  r.append(propose_recall_sd[i]-cdragan_recall_sd[i])
print(stats.shapiro(r))
# Out:
# ShapiroResult(statistic=0.9166437983512878, pvalue=0.3298109173774719)

# %%
stat, p = ttest_rel(propose_recall_sd , cdragan_recall_sd, axis=0, alternative='greater')
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('Probably the same distribution')
else:
	print('Probably different distributions')
# Out:
# stat=0.701, p=0.250
# Probably the same distribution

# %%
r=[]
for i in range(10):
  r.append(propose_recall_sd[i]-noaug_recall_sd[i])
print(stats.shapiro(r))

stat, p = ttest_rel(propose_recall_sd , noaug_recall_sd, axis=0, alternative='greater')
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('Probably the same distribution')
else:
	print('Probably different distributions')
# Out:
# ShapiroResult(statistic=0.9232872724533081, pvalue=0.38518965244293213)
# stat=3.513, p=0.003
# Probably different distributions

# %%
print(  (np.mean(propose_recall_sd)-np.mean(bagangp_recall_sd))  / np.mean(bagangp_recall_sd) *100 )
print(  (np.mean(propose_recall_sd)-np.mean(cdragan_recall_sd))  / np.mean(cdragan_recall_sd) *100 )
print(  (np.mean(propose_recall_sd)-np.mean(noaug_recall_sd))  / np.mean(noaug_recall_sd) *100 )
print(  (np.mean(propose_recall_sd)-np.mean(smote_recall_sd))  / np.mean(smote_recall_sd) *100 )
print(  (np.mean(propose_recall_sd)-np.mean(bsmote_recall_sd))  / np.mean(bsmote_recall_sd) *100 )
# print(  (np.mean(propose_recall_sd)-np.mean(adasyn_recall_sd))  / np.mean(adasyn_recall_sd) *100 )
print(  (np.mean(propose_recall_sd)-np.mean(cooperative_recall_sd))  / np.mean(cooperative_recall_sd) *100 )
# Out:
# 1.8003100338218718
# 0.8498682442455165
# 3.8846644735659512
# 4.878225835722848
# 4.893454822666731
# 3.194585810967666

# %%
import glob

propose_precision = []
propose_precision_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/PRECISION/PROPOSE')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
filelist=sorted(filelist)
a = 0
for file in filelist:
  print(file)
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  propose_precision_sd.append(result[148:149])

print("propose")
print(a/len(filelist))
propose_precision.append(a/len(filelist))
print(len(filelist))
print(np.std(propose_precision_sd))
print(a/len(filelist)-1.96*(np.std(propose_precision_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(propose_precision_sd)/math.sqrt(len(filelist))))

bagangp_precision  = []
bagangp_precision_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/PRECISION/BAGANGP')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  print(file)
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  bagangp_precision_sd.append(result[148:149])

print("bagangp")
print(a/len(filelist))
bagangp_precision .append(a/len(filelist))
print(len(filelist))
print(np.std(bagangp_precision_sd))
print(a/len(filelist)-1.96*(np.std(bagangp_precision_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(bagangp_precision_sd)/math.sqrt(len(filelist))))


cdragan_precision  = []
cdragan_precision_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/PRECISION/CDRAGAN')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  cdragan_precision_sd.append(result[148:149])

print("cdragan")
print(a/len(filelist))
cdragan_precision .append(a/len(filelist))
print(len(filelist))
print(np.std(cdragan_precision_sd))
print(a/len(filelist)-1.96*(np.std(cdragan_precision_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(cdragan_precision_sd)/math.sqrt(len(filelist))))



noaug_precision = []
noaug_precision_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/PRECISION/NOAUG')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  noaug_precision_sd.append(result[148:149])

print("noaug")
print(a/len(filelist))
noaug_precision.append(a/len(filelist))
print(len(filelist))
print(np.std(noaug_precision_sd))
print(a/len(filelist)-1.96*(np.std(noaug_precision_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(noaug_precision_sd)/math.sqrt(len(filelist))))


smote_precision = []
smote_precision_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/PRECISION/SMOTE')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  smote_precision_sd.append(result[148:149])

print("smote")
print(a/len(filelist))
smote_precision .append(a/len(filelist))
print(len(filelist))
print(np.std(smote_precision_sd))
print(a/len(filelist)-1.96*(np.std(smote_precision_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(smote_precision_sd)/math.sqrt(len(filelist))))



bsmote_precision  = []
bsmote_precision_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/PRECISION/BSMOTE')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  bsmote_precision_sd.append(result[148:149])

print("bsmote")
print(a/len(filelist))
bsmote_precision .append(a/len(filelist))
print(len(filelist))
print(np.std(bsmote_precision_sd))
print(a/len(filelist)-1.96*(np.std(bsmote_precision_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(bsmote_precision_sd)/math.sqrt(len(filelist))))




# adasyn_precision = []
# adasyn_precision_sd = []

# os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/PRECISION/ADASYN')
# path = os.getcwd()
# filelist = glob.glob(os.path.join(path, "*.CSV"))
# a = 0
# for file in filelist:
#   result = pd.read_csv(file)
#   result = result.values
#   a = a +np.mean(result[148:149])
#   adasyn_precision_sd.append(result[148:149])

# print("adasyn")
# print(a/len(filelist))
# adasyn_precision .append(a/len(filelist))
# print(len(filelist))
# print(np.std(adasyn_precision_sd))
# print(a/len(filelist)-1.96*(np.std(adasyn_precision_sd)/math.sqrt(len(filelist))))
# print(a/len(filelist)+1.96*(np.std(adasyn_precision_sd)/math.sqrt(len(filelist))))




cooperative_precision = []
cooperative_precision_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/PRECISION/COOPERATIVE')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  cooperative_precision_sd.append(result[148:149])

print("cooperative")
print(a/len(filelist))
cooperative_precision .append(a/len(filelist))
print(len(filelist))
print(np.std(cooperative_precision_sd))
print(a/len(filelist)-1.96*(np.std(cooperative_precision_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(cooperative_precision_sd)/math.sqrt(len(filelist))))



cooperative_precision = []
cooperative_precision_sd = []

os.chdir('/content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/PRECISION/COOPERATIVE/9')
path = os.getcwd()
filelist = glob.glob(os.path.join(path, "*.CSV"))
a = 0
for file in filelist:
  result = pd.read_csv(file)
  result = result.values
  a = a +np.mean(result[148:149])
  cooperative_precision_sd.append(result[148:149])

print("cooperative")
print(a/len(filelist))
cooperative_precision .append(a/len(filelist))
print(len(filelist))
print(np.std(cooperative_precision_sd))
print(a/len(filelist)-1.96*(np.std(cooperative_precision_sd)/math.sqrt(len(filelist))))
print(a/len(filelist)+1.96*(np.std(cooperative_precision_sd)/math.sqrt(len(filelist))))
# Out:
# /content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/PRECISION/PROPOSE/precision_0_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/PRECISION/PROPOSE/precision_1_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/PRECISION/PROPOSE/precision_2_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/PRECISION/PROPOSE/precision_3_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/PRECISION/PROPOSE/precision_4_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/PRECISION/PROPOSE/precision_5_EBM.CSV
# /content/drive/My Drive/Colab Notebooks/Johnson/imbalanceGAN_scale/imbalanceGAN/RESULT/PRECISION/PROPOSE/precision_6_EBM.CSV
# ...

# %%
r=[]
for i in range(10):
  r.append(propose_precision_sd[i]-cdragan_precision_sd[i])
print(stats.shapiro(r))
# Out:
# ShapiroResult(statistic=0.9137772917747498, pvalue=0.30795806646347046)

# %%
stat, p = ttest_rel(propose_precision_sd , cdragan_precision_sd, axis=0, alternative='greater')
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('Probably the same distribution')
else:
	print('Probably different distributions')
# Out:
# stat=0.693, p=0.253
# Probably the same distribution

# %%
r=[]
for i in range(10):
  r.append(propose_precision_sd[i]-noaug_precision_sd[i])
print(stats.shapiro(r))

stat, p = ttest_rel(propose_precision_sd , noaug_precision_sd, axis=0, alternative='greater')
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('Probably the same distribution')
else:
	print('Probably different distributions')
# Out:
# ShapiroResult(statistic=0.9260010123252869, pvalue=0.40972912311553955)
# stat=3.703, p=0.002
# Probably different distributions

# %%
print(  (np.mean(propose_precision_sd)-np.mean(bagangp_precision_sd))  / np.mean(bagangp_precision_sd) *100 )
print(  (np.mean(propose_precision_sd)-np.mean(cdragan_precision_sd))  / np.mean(cdragan_precision_sd) *100 )
print(  (np.mean(propose_precision_sd)-np.mean(noaug_precision_sd))  / np.mean(noaug_precision_sd) *100 )
print(  (np.mean(propose_precision_sd)-np.mean(smote_precision_sd))  / np.mean(smote_precision_sd) *100 )
print(  (np.mean(propose_precision_sd)-np.mean(bsmote_precision_sd))  / np.mean(bsmote_precision_sd) *100 )
# print(  (np.mean(propose_precision_sd)-np.mean(adasyn_precision_sd))  / np.mean(adasyn_precision_sd) *100 )
print(  (np.mean(propose_precision_sd)-np.mean(cooperative_precision_sd))  / np.mean(cooperative_precision_sd) *100 )
# Out:
# 3.0677946334370794
# 1.4359820693339935
# 6.600637538946389
# 7.392275606119035
# 7.2588564678267105
# 4.354729283112559
